# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
# generate synthetic two-dimensional data
X, y = make_blobs(n_samples = 100,random_state=1)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
y
# Out:
# array([0, 1, 1, 1, 2, 2, 2, 1, 0, 0, 1, 1, 2, 0, 2, 2, 2, 0, 1, 1, 2, 1,
#        2, 0, 1, 2, 2, 0, 0, 2, 0, 0, 2, 0, 1, 2, 1, 1, 1, 2, 2, 1, 0, 1,
#        1, 2, 0, 0, 0, 0, 1, 2, 2, 2, 0, 2, 1, 1, 0, 0, 1, 2, 2, 1, 1, 2,
#        0, 2, 0, 1, 1, 1, 2, 0, 0, 1, 2, 2, 0, 1, 0, 1, 1, 2, 0, 0, 0, 0,
#        1, 0, 2, 0, 0, 1, 1, 2, 2, 0, 2, 0])

# %%
print(X[:10,0])
print(X[:10,1])
# Out:
# [ -0.79415228  -9.15155186 -11.44182631  -9.76761777  -4.53655648
#   -6.26302115  -6.38481234  -9.20490564  -2.76017908  -1.17104176]
# [ 2.10495117 -4.81286449 -4.45781441 -3.19133737 -8.40186288 -8.10666081
#  -8.4730297  -4.57687928  5.55121358  4.33091816]

# %%
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# Out:
# Text(0, 0.5, 'Feature2')

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
labels = kmeans.labels_
labels
# Out:
# array([0, 2, 3, 3, 1, 1, 1, 2, 4, 0, 2, 3, 1, 4, 1, 1, 1, 0, 3, 3, 1, 3,
#        1, 0, 2, 1, 1, 0, 0, 1, 4, 0, 1, 0, 2, 1, 2, 3, 2, 1, 1, 2, 0, 3,
#        2, 1, 4, 0, 4, 0, 2, 1, 1, 1, 4, 1, 3, 3, 4, 0, 3, 1, 1, 2, 3, 1,
#        4, 1, 0, 2, 3, 2, 1, 4, 4, 2, 1, 1, 0, 3, 4, 3, 3, 1, 0, 0, 4, 0,
#        3, 4, 1, 0, 4, 3, 2, 1, 1, 4, 1, 0])

# %%
# Centroids 
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ -1.33824945,   3.58202335],
#        [ -6.58196786,  -8.17239339],
#        [ -9.54613654,  -4.51849239],
#        [-10.468699  ,  -3.31041475],
#        [ -1.63933544,   5.29379975]])

# %%
# Drawing data points in different colors based on label 
plt.scatter(X[:,0],X[:,1], c=labels.astype(np.float))
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# draw centers 
plt.scatter(centers[:,0], centers[:,1], c="red", marker="s")
plt.show()

# %%
print(kmeans.transform(X[:10]))
print(labels[:10])
# Out:
# [[ 1.57409782 11.79502525 10.97575661 11.08706644  3.29895284]
#  [11.46829701  4.2295622   0.4922926   1.998057   12.59277799]
#  [12.91205857  6.11688819  1.89666062  1.50449418 13.82688707]
#  [10.81354085  5.91263769  1.34550897  0.71112187 11.7501713 ]
#  [12.40333411  2.05824293  6.33849026  7.81749058 13.99875226]
#  [12.68379729  0.32564978  4.86351717  6.37900481 14.17571207]
#  [13.0687452   0.35951702  5.06283873  6.58260764 14.56176996]
#  [11.33366541  4.4505645   0.34619006  1.7891635  12.43656532]
#  [ 2.42890799 14.24582247 12.14282491 11.74520055  1.15002276]
#  [ 0.76733424 13.6239099  12.18418153 12.03479949  1.07071936]]
# [0 2 3 3 1 1 1 2 4 0]

# %%
kmeans.inertia_
# Out:
# 112.05653036061504

# %%
kmeans.n_iter_
# Out:
# 6

# %%
kmeans.score(X)
# Out:
# -156.2828925117

# %%
# Elbow technique to find out the best K
cost = []
for k in range(2,6):
   kmeans = KMeans(n_clusters=k)
   kmeans.fit(X)
   cost.append(kmeans.inertia_)

# %%
plt.plot(range(2,6), cost)
plt.xlabel("K")
plt.ylabel("Inertia (Cost)")
# Out:
# Text(0, 0.5, 'Inertia (Cost)')
